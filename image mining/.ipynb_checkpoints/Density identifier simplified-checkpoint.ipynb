# %%
import numpy as np
import pandas as pd
import pathlib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
from skimage.filters import threshold_otsu
from scipy import ndimage

# %% [markdown]
# ### Load the data

# %%
train_paths = pathlib.Path('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15').glob('*.jpeg')
train_sorted=sorted([path for path in train_paths])
im_path=train_sorted[10:21]
im_path
# Out:
# 10

# %% [markdown]
# ### Read and Preprocess the image

# %%
plt.figure(figsize=(10,6))
bgrimg = cv2.imread(str(im_path))
plt.subplot(131)
plt.imshow(bgrimg)
plt.title('Origin')
plt.subplot(132)
grayimg = cv2.cvtColor(bgrimg,cv2.COLOR_BGR2GRAY)
plt.imshow(grayimg)
plt.title('Gray')
plt.subplot(133)
img_blur=cv2.blur(grayimg,(7,7),0) #reduce the noise
plt.imshow(img_blur)
plt.title('Blurred with 7x7 matrix')
# Out:
# Text(0.5, 1.0, 'Blurred with 7x7 matrix')

# %% [markdown]
# ### Use the Threshold to fliter the white blood cell

# %%
thresh_val=np.percentile(img_blur.flatten(),0.1)
mask=np.where(img_blur>thresh_val,0,1)
plt.imshow(mask)
plt.title('Object')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ### Label the cells

# %%
labels,nlabels=ndimage.label(mask)
slices=ndimage.find_objects(labels)
nlabels,slices
# Out:
# (7,
#  [(slice(0, 2, None), slice(8, 11, None)),
#   (slice(45, 49, None), slice(173, 176, None)),
#   (slice(92, 96, None), slice(98, 101, None)),
#   (slice(95, 98, None), slice(226, 228, None)),
#   (slice(144, 147, None), slice(144, 147, None)),
#   (slice(185, 189, None), slice(157, 161, None)),
#   (slice(242, 248, None), slice(251, 256, None))])

# %% [markdown]
# ### Output the Region

# %%
region=[]
for i in range(0,nlabels):
    sub_region={'xmin':slices[i][1].start,'xmax':slices[i][1].stop,'ymin':slices[i][0].start,'ymax':slices[i][0].stop}
    region.append(sub_region)
region
# Out:
# [{'xmax': 11, 'xmin': 8, 'ymax': 2, 'ymin': 0},
#  {'xmax': 176, 'xmin': 173, 'ymax': 49, 'ymin': 45},
#  {'xmax': 101, 'xmin': 98, 'ymax': 96, 'ymin': 92},
#  {'xmax': 228, 'xmin': 226, 'ymax': 98, 'ymin': 95},
#  {'xmax': 147, 'xmin': 144, 'ymax': 147, 'ymin': 144},
#  {'xmax': 161, 'xmin': 157, 'ymax': 189, 'ymin': 185},
#  {'xmax': 256, 'xmin': 251, 'ymax': 248, 'ymin': 242}]

# %% [markdown]
# ### Test the Region

# %%
bgrimg = cv2.imread(str(im_path))
plt.figure(figsize=(10,8))
plt.subplot(121)
plt.imshow(bgrimg)
plt.title('Origin Plot')
plt.subplot(122)
for i in range(0,len(region)):
    testimg=cv2.rectangle(bgrimg, (region[i]['xmin'],region[i]['ymin']), (region[i]['xmax'],region[i]['ymax']),(0,0,255),1)
plt.imshow(testimg)
plt.title('Object Detection Plot')
# Out:
# Text(0.5, 1.0, 'Object Detection Plot')

# %% [markdown]
# ### Function

# %%
def region_detect(imgpath):
    bgrimg = cv2.imread(str(imgpath))
    grayimg = cv2.cvtColor(bgrimg,cv2.COLOR_BGR2GRAY)
    img_blur=cv2.blur(grayimg,(7,7),0)
    # Use threshold to fliter out the white blood cell 
    thresh_val=np.percentile(img_blur.flatten(),0.1)
    mask=np.where(img_blur>thresh_val,0,1)
    # Detect and label the white blood cell 
    labels,nlabels=ndimage.label(mask)
    slices=ndimage.find_objects(labels)
    # Output the region 
    region=[]
    for i in range(0,nlabels):
        sub_region={'xmin':slices[i][1].start,'xmax':slices[i][1].stop,'ymin':slices[i][0].start,'ymax':slices[i][0].stop}
        region.append(sub_region)
    return region

# %%
im_path=train_sorted[120]

# %%
region=region_detect(im_path)
region
# Out:
# [{'xmax': 61, 'xmin': 57, 'ymax': 97, 'ymin': 95},
#  {'xmax': 202, 'xmin': 196, 'ymax': 168, 'ymin': 162},
#  {'xmax': 153, 'xmin': 146, 'ymax': 170, 'ymin': 163}]

# %%
bgrimg = cv2.imread(str(im_path))
plt.figure(figsize=(10,8))
plt.subplot(121)
plt.imshow(bgrimg)
plt.title('Origin Plot')
plt.subplot(122)
for i in range(0,len(region)):
    testimg=cv2.rectangle(bgrimg, (region[i]['xmin'],region[i]['ymin']), (region[i]['xmax'],region[i]['ymax']),(0,0,255),1)
plt.imshow(testimg)
plt.title('Object Detection Plot')
# Out:
# Text(0.5, 1.0, 'Object Detection Plot')

# %% [markdown]
# # Multiple Plot Testing

# %%
train_paths = pathlib.Path('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15').glob('*.jpeg')
train_sorted=sorted([path for path in train_paths])
im_path=train_sorted[60:70]
im_path,len(im_path)
# Out:
# ([PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_19.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_2.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_20.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_21.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_22.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_23.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_24.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_25.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_26.jpeg'),
#   PosixPath('/Users/StevenTseng/Desktop/gallenco/slide_file/a_files/15/10_27.jpeg')],
#  10)

# %%
plt.figure(figsize=(20,10))
for i in range(0,len(im_path)):
    plt.subplot(2,len(im_path)/2,i+1)
    plt.imshow(cv2.imread(str(im_path[i])))
    temp=i
    plt.title(('Plot_'+ str(i)))

# %%
def get_detected_img(imgpath):
    test_region=region_detect(imgpath)
    bgrimg = cv2.imread(str(imgpath))
    for i in range(0,len(region)):
        testimg=cv2.rectangle(bgrimg, (region[i]['xmin'],region[i]['ymin']), (region[i]['xmax'],region[i]['ymax']),(0,0,255),1)
